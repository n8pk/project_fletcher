# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

from sklearn.decomposition import PCA

import plotly.plotly as py
import plotly.graph_objs as go

# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
links = pd.read_pickle('pkl/mvp_links.pkl')

tfidf = pd.read_pickle('tfidf.pkl')

nmf_embedding = pd.read_pickle('nmf.pkl')

# %% [markdown]
# # PCA (raw & nmf)

# %% [markdown]
# dimensionality reduction!!! this is a must, because 4-D and up
#
# is not something you want to try plotting.
#
#
# let's start with some 2-D plots to get a general idea of similarity

# %%
pca = PCA(n_components = 2, random_state = 42)
pca.fit(tfidf.toarray())
pcafeatures_train = pca.transform(tfidf.toarray())

# %%
raw_x2 = []
raw_y2 = []
for i in pcafeatures_train:
    raw_x2.append(i[0])
    raw_y2.append(i[1])

# %% [markdown]
# the raw data before NMF is actually showing some signs
#
# of separation, note the central gap, and bottom left spike

# %%
plt.scatter(raw_x2,raw_y2);

# %%
nmf_pca = PCA(n_components = 2, random_state = 42)
nmf_pca.fit(nmf_embedding)
nmf_pcafeatures_train = nmf_pca.transform(nmf_embedding)

# %%
nmf_x2 = []
nmf_y2 = []
for i in nmf_pcafeatures_train:
    nmf_x2.append(i[0])
    nmf_y2.append(i[1])

# %% [markdown]
# now the groups are clearly separated, if this was project 1 or 2
#
# this plot might even make it into the presentation!

# %%
plt.scatter(nmf_x2, nmf_y2);

# %% [markdown]
# # plotly 3-D (raw & nmf)

# %% [markdown]
# ## plot labels

# %% [markdown]
# plotly is a time sink, but it churns out some really
#
# beautiful stuff. labels are a must if the graph will
#
# end up being presented.

# %%
topics = ['daytime, anxiety, depression',
          'nighttime, insomnia',
          'happy feelings, nerve pain',
          'creativity, chronic pain']

# %%
plot_strain_names = []
plot_strain_type = []
plot_topic = []

for name in links:
    plot_strain_names.append(name.split('/')[2].replace('-', ' '))
    plot_strain_type.append(name.split('/')[1])
    
for name in nmf_embedding:
    plot_topic.append(
        topics[name.argmax()]
    )

# %%
plot_text = []

count = 0
while count < len(plot_strain_names):
    plot_text.append(
        'Name: ' + plot_strain_names[count] + '<br>'
        + 'Species: ' + plot_strain_type[count] + '<br>'
        + 'Uses: ' + plot_topic[count]       
    )
    count += 1

# %%
plot_text[0]
# Out:
# 'Name: blue dream<br>Species: hybrid<br>Uses: daytime, anxiety, depression'

# %% [markdown]
# ## plotting

# %%
raw_x3 = []
raw_y3 = []
raw_z3 = []
for i in pcafeatures_train:
    raw_x3.append(i[0])
    raw_y3.append(i[1])
    raw_z3.append(i[2])

# %% [markdown]
# not interpretable enough for a presentation but still interesting

# %%
trace = go.Scatter3d(
    x = raw_x3,
    y = raw_y3,
    z = raw_z3,
    text = plot_text,
    hoverinfo = 'none+none+none+text',
    mode = 'markers',
    marker = dict(
        size = 10,
        color = nmf_embedding.argmax(axis=1),                
        colorscale = 'Greens',   
        opacity = 0.9
    )
)


plot_data = [trace]
layout = go.Layout(
    title = 'PCA on TF-IDF Output',
    margin = dict(
        l = 0,
        r = 0,
        b = 0,
        t = 0
    )
)
fig = go.Figure(data = plot_data, layout = layout)
py.iplot(fig)
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~n8pk/86.embed" height="525px" width="100%"></iframe>

# %%
pca = PCA(n_components = 3, random_state = 42)
pca.fit(tfidf.toarray())
pcafeatures_train = pca.transform(tfidf.toarray())

# %%
nmf_pca = PCA(n_components = 3, random_state = 42)
nmf_pca.fit(nmf_embedding)
nmf_pcafeatures_train = nmf_pca.transform(nmf_embedding)

# %%
nmf_x3 = []
nmf_y3 = []
nmf_z3 = []
for i in nmf_pcafeatures_train:
    nmf_x3.append(i[0])
    nmf_y3.append(i[1])
    nmf_z3.append(i[2])

# %% [markdown]
# no here's a thing of beauty, it looks like a caltrop
#
# but each spike is a very clearly separated group!

# %%
trace = go.Scatter3d(
    x = nmf_x3,
    y = nmf_y3,
    z = nmf_z3,
    text = plot_text,
    hoverinfo = 'none+none+none+text',
    mode = 'markers',
    marker = dict(
        size = 10,
        color = nmf_embedding.argmax(axis=1),                
        colorscale = 'Jet',   
        opacity = 0.9
    )
)

plot_data = [trace]
layout = go.Layout(
    margin = dict(
        l = 0,
        r = 0,
        b = 0,
        t = 0
    )
)
fig = go.Figure(data = plot_data, layout = layout)
py.iplot(fig)
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~n8pk/106.embed" height="525px" width="100%"></iframe>

# %% [markdown]
# # Basic Recommender

# %% [markdown]
# this is a toe-dip into recommendation systems, however
#
# something more advanced such as collaborative filtering
#
# or an ensemble of several recommendation methods isn't
#
# possible with just text data. cosine similarity is simple
#
# we just mesaure the angles between points, and take the closest
#
# matches to the original. think of a line shooting out from the
#
# origin towards our point of interest, the points where the
#
# angle of the line (not its length) has to adjust the least
#
# are the points that are 'closest' to the original!

# %%
npt = nmf_pcafeatures_train

# %%
def n_cosdist(target, array, n_recs):
    
    '''
    input target and array to get n cosine distances
    '''
    
    cos_distances = []
    
    for idx, vec in enumerate(array):
        tv = np.dot(target, vec)
        tv_norm = np.linalg.norm(target)*np.linalg.norm(vec)
        cos_distances.append((tv/tv_norm, idx))
        
    cos_distances = sorted(cos_distances, reverse = True)
    
    return cos_distances[1:n_recs+1]

# %%
def recommendations(target, names_array, model_transform, n_recs):
    
    '''
    input: product name as a string with all names available,
    model to transform with, and number of recs
    output: names of n top recommendations
    '''
    
    recs = []
    
    if target not in names_array:
        print("Sorry! I can't find '{}'.".format(target))
    
    for idx, name in enumerate(names_array):
        if name == target:
            recs = n_cosdist(target = model_transform[idx], array = model_transform, n_recs = n_recs)
            
    for idx, rec in enumerate(recs):
        print('Recommendation {}:'.format(idx+1) + '\n' + names_array[rec[1]])

# %%
recommendations('purple kush', plot_strain_names, npt, 3)
# Out:
# Recommendation 1:
# master kush
# Recommendation 2:
# hindu kush
# Recommendation 3:
# la confidential
